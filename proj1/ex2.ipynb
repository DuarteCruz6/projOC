# %% [markdown]
# # 2- First Steps
# Please justify all your answers with values from the experiments.
#
# ### 1- What is the cache capacity of the computer you used (please write the workstation name)?
#
# | Data                  |  Test1      |  Test2      |  Test3      |  Test4      |  Test5      |  Test6      |
# | :---------------:     |:-----------:|:-----------:|:-----------:|:-----------:|:-----------:|:-----------:|
# | Array Size  (B)       |4096         |8192         |16384        |32768        |65536        |131072       |
# | t2-t1 (ns)            |2.381 x 10^6 |1.296x10^6   |2.574x10^6   |5.135x10^6   |10.316x10^6  |20.954x10^6  |
# | #accesses a[i]        |409600       |819200       |1638400      |3276800      |6553600      |13107200     |
# | #mean access time (ns)|5.812        |1.581        |1.571        |1.567        |1.574        |1.599        |
#
# continuacao
#
# | Data                  |  Test7      |  Test8      |  Test9      |  Test10     |  Test11     |
# | :---------------:     |:-----------:|:-----------:|:-----------:|:-----------:|:-----------:|
# | Array Size  (B)       | 262144      |524288       |1048576      |2097152      |4194304      |
# | t2-t1 (ns)            | 41.608x10^6 |83.796x10^6  |165.349x10^6 |332.788x10^6 |669.693x10^6 |
# | #accesses a[i]        | 26214400    |52428800     |104857600    |209715200    |419430400    |
# | #mean access time (ns)| 1.587       |1.598        |1.577        |1.587        |1.597        |
#
# #### Justification/Calculations
#
# Consider the data presented in Figure 1. Answer the following questions (2, 3, 4) about the machine
# used to generate that data.
#
# ### 2- What is the cache capacity?
#
# ### 3- What is the size of each cache block?
#
# ### 4- What is the L1 cache miss penalty time?
